# %%
import pandas as pd

# %%
df = pd.read_parquet('../assets/sample.parquet')

# %%
df
# Out:
#                                  email  \
# 0       b'rickie.6cl60vv5@example.net'
# 1         b'olaf.14ymhjtf@example.org'
# 2      b'rebecca.3a623w6u@example.com'
# 3       b'yvonne.qx06kzs6@example.org'
# 4       b'juston.apls64ti@example.org'
# ..                                 ...
# 995        b'una.inxgk1lq@example.com'
# 996  b'raphaelle.kk6ikbeq@example.net'
# 997   b'josianne.ceoqsbol@example.org'
# 998     b'anabel.r5dxwncd@example.com'
# 999   b'patricia.eft3oxwx@example.org'
#
#                                         name      gender  \
# 0    b'\xe5\xbd\xad\xe6\x9d\xb0\xe8\xa3\x95'  b'unknown'
# 1    b'\xe9\xad\x8f\xe7\x92\x87\xe7\x9b\x88'  b'unknown'
# 2    b'\xe7\x86\x8a\xe7\x95\x85\xe7\x91\x9e'  b'unknown'
# 3    b'\xe5\xad\x9f\xe7\x91\x9c\xe6\x98\x95'  b'unknown'
# 4    b'\xe9\x92\xb1\xe6\x9d\x89\xe6\x99\x96'  b'unknown'
# ..                                       ...         ...
# 995  b'\xe5\x94\x90\xe4\xba\x91\xe7\x87\x95'  b'unknown'
# ...

# %%
df.head()
# Out:
#                              email                                     name  \
# 0   b'rickie.6cl60vv5@example.net'  b'\xe5\xbd\xad\xe6\x9d\xb0\xe8\xa3\x95'
# 1     b'olaf.14ymhjtf@example.org'  b'\xe9\xad\x8f\xe7\x92\x87\xe7\x9b\x88'
# 2  b'rebecca.3a623w6u@example.com'  b'\xe7\x86\x8a\xe7\x95\x85\xe7\x91\x9e'
# 3   b'yvonne.qx06kzs6@example.org'  b'\xe5\xad\x9f\xe7\x91\x9c\xe6\x98\x95'
# 4   b'juston.apls64ti@example.org'  b'\xe9\x92\xb1\xe6\x9d\x89\xe6\x99\x96'
#
#        gender                       created_at  \
# 0  b'unknown' 2020-08-10 13:01:25.925310+00:00
# 1  b'unknown' 2021-11-13 13:00:25.903489+00:00
# 2  b'unknown' 2020-03-27 01:20:25.909394+00:00
# 3  b'unknown' 2022-07-04 00:23:25.871170+00:00
# 4  b'unknown' 2023-11-15 00:40:25.923932+00:00
#
#                    last_visited_at                  last_watched_at  \
# 0 2024-05-04 09:50:25.925310+00:00 2024-04-16 14:54:25.925310+00:00
# 1 2024-04-25 20:57:25.903489+00:00 2024-02-14 23:31:25.903489+00:00
# ...

# %%
df.describe()
# Out:
#                                    email  \
# count                               1000
# unique                              1000
# top     b'patricia.eft3oxwx@example.org'
# freq                                   1
# mean                                 NaN
# min                                  NaN
# 25%                                  NaN
# 50%                                  NaN
# 75%                                  NaN
# max                                  NaN
#
#                                            name      gender  \
# count                                      1000        1000
# unique                                      986           1
# top     b'\xe9\x99\x86\xe5\x87\x9d\xe9\x9b\x81'  b'unknown'
# freq                                          2        1000
# mean                                        NaN         NaN
# min                                         NaN         NaN
# 25%                                         NaN         NaN
# ...
